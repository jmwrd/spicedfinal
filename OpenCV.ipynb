# %%
import cv2

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
img = cv2.imread("wimmel.jpg")

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
img.set_size_inches(18.5, 10.5, forward=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-bbdf59d6dd30> in <module>
# ----> 1 img.set_size_inches(18.5, 10.5, forward=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_size_inches'

# %%
""" C++ was used for the programming of OpenCV. Here the colors are upside down: blue and green are swapped. 

Convert the color """
# Out:
# ' C++ was used for the programming of OpenCV. Here the colors are upside down: blue and green are swapped. \n\nConvert the color '

# %%
img2=cv2.imread("wimmel.jpg")
plt.imshow(img2[1::,1::,::-1])

# %%
g = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(g)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
""""Matplotlib does not show it in gray but colors this a bit (makes sense for mathematical plots)"""
# Out:
# '"Matplotlib does not show it in gray but colors this a bit (makes sense for mathematical plots)'

# %%
print(img.shape)
print(g.shape)
# Out:
# (2224, 3549, 3)
# (2224, 3549)

# %%
cv2.rectangle(img2, (200,200), (500,500), (0,0,255), 20)
plt.imshow(g, "gray")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, "gray")
plt.show()

# %%
### Classifier laden

# %%
###Classifier ist schon fertig trainiert auf Gesichter

# %%
cd haarcascades
# Out:
# /Users/jasminwrede/Documents/spiced_projects/final/haarcascades

# %%
ls
# Out:
# haarcascade_eye.xml*
# haarcascade_eye_tree_eyeglasses.xml*
# haarcascade_frontalcatface.xml*
# haarcascade_frontalcatface_extended.xml*
# haarcascade_frontalface_alt.xml*
# haarcascade_frontalface_alt2.xml*
# haarcascade_frontalface_alt_tree.xml*
# haarcascade_frontalface_default.xml*
# haarcascade_fullbody.xml*
# haarcascade_lefteye_2splits.xml*
# haarcascade_licence_plate_rus_16stages.xml*
# haarcascade_lowerbody.xml*
# haarcascade_profileface.xml*
# haarcascade_righteye_2splits.xml*
# haarcascade_russian_plate_number.xml*
# haarcascade_smile.xml*
# haarcascade_upperbody.xml*
# wimmel.jpg

# %%
classifier = cv2.CascadeClassifier("haarcascade_frontalface_alt2.xml")

# %%
faces = classifier.detectMultiScale(gray, minNeighbors=10)

# %%
print(faces)
# Out:
# [[2703 1243   62   62]]

# %%
""" List with

coordinate coordinate width length

14 times"""
# Out:
# ' List with\n\ncoordinate coordinate width length\n\n14 times'

# %%
c= img.copy()
for face in faces:
    x, y, w, h = face
    cv2.rectangle(c, (x, y), (x+w, y+h), (0, 255, 0), 10)
    print(face)

i = cv2.cvtColor(c, cv2.COLOR_BGR2RGB)
plt.imshow(i)
plt.show()
# Out:
# [2703 1243   62   62]
